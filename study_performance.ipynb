# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('study_performance.csv')
dataset
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
dataset.describe() # describe function usually worl on numerical function only 
                                #so wile include all it disctibes the all data set
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
dataset.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
#changing object dtype to category  to save memory
dataset['gender']=dataset['gender'].astype("category")
dataset['race_ethnicity']=dataset['race_ethnicity'].astype("category")
dataset['parental_level_of_education']=dataset['parental_level_of_education'].astype("category")
dataset['lunch']=dataset['lunch'].astype("category")
dataset['rtest_preparation_course']=dataset['test_preparation_course'].astype("category")
dataset['test_preparation_course']=dataset['test_preparation_course'].astype("category")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   category
#  1   race_ethnicity               1000 non-null   category
#  2   parental_level_of_education  1000 non-null   category
#  3   lunch                        1000 non-null   category
#  4   test_preparation_course      1000 non-null   category
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
#  8   rtest_preparation_course     1000 non-null   category
# dtypes: category(6), int64(3)
# memory usage: 30.3 KB

# %%
list_col=  dataset.select_dtypes(['category']).columns
list_col1=  dataset.select_dtypes(['int64']).columns
print(list_col)
print("\n")
print(list_col1)
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'rtest_preparation_course'],
#       dtype='object')
#
#
# Index(['math_score', 'reading_score', 'writing_score'], dtype='object')

# %%
a= dataset['gender'].value_counts()
b= dataset['race_ethnicity'].value_counts()
c= dataset['parental_level_of_education'].value_counts()
d= dataset['lunch'].value_counts()
e= dataset['test_preparation_course'].value_counts()
f= dataset['rtest_preparation_course'].value_counts()
g= dataset['math_score'].value_counts()
h= dataset['reading_score'].value_counts()
i= dataset['writing_score'].value_counts()
print(a)
print("\n")
print(b)
print("\n")
print(c)
print("\n")
print(d)
print("\n")
print(e)
print("\n")
print(f)
print("\n")
print(g)
print("\n")
print(h)
print("\n")
print(i)
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64
#
#
# race_ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
#
#
# parental_level_of_education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
#
#
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64
#
#
# test_preparation_course
# none         642
# completed    358
# Name: count, dtype: int64
#
#
# rtest_preparation_course
# none         642
# completed    358
# Name: count, dtype: int64
#
#
# math_score
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: count, Length: 81, dtype: int64
#
#
# reading_score
# 72    34
# 74    33
# 64    32
# 67    30
# 73    30
#       ..
# 28     1
# 26     1
# ...

# %%
# # Function to create barplots that indicate percentage for each category.
def bar_perc(plot, feature):
    total = len(feature) # length of the column
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        plot.annotate(percentage, (x, y), size = 12) # annotate the percentage

# %%
no_of_male = len(dataset[dataset['gender'] == 'male'])
no_of_female = len(dataset[dataset['gender'] == 'female'])

plt.bar(['male','female'],[no_of_male,no_of_female],color = ['r','g'],label = ['male','female'])
plt.legend()
plt.show()

# %%
#for education level
no_of_a = len(dataset[dataset['parental_level_of_education'] == "some college"])
no_of_b = len(dataset[dataset['parental_level_of_education'] == "associate's degree"])
no_of_c = len(dataset[dataset['parental_level_of_education'] == 'high school'])



plt.bar(["some college","associate's degree","high school"],[no_of_a,no_of_b,no_of_c], color = ['r','g','b','b'], label=["some college","associate's degree","high school",])
plt.title('No of people with Education level')
plt.legend()
plt.show()

# %%
plot_data = dict(dataset['race_ethnicity'].value_counts())
print(plot_data)
plt.bar(plot_data.keys(),plot_data.values(),color = ['r','g','b'],label = plot_data.keys())
plt.legend()
plt.show()
# plot_data
# plot_data.keys()
# Out:
# {'group C': 319, 'group D': 262, 'group B': 190, 'group E': 140, 'group A': 89}

# %%
race_ethnicity= ('group C','group D','group B','group E','group A')
race= sorted(race_ethnicity)
print(race)
# Out:
# ['group A', 'group B', 'group C', 'group D', 'group E']

# %%
dataset['lunch'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
dataset
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
corr_dataset = dataset[['math_score','reading_score','writing_score']]

# %%
plt.figure(figsize=(15,5))
sns.heatmap(corr_dataset.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.pairplot(data=dataset)
plt.show()

# %%
plt.figure(figsize=(13,5))
ax=sns.countplot(x='parental_level_of_education',hue='test_preparation_course',data=dataset)

# %%
# Assuming 'dataset' is your DataFrame
plt.figure(figsize=(15, 7))
sns.barplot(
    x='gender', 
    y='race_ethnicity', 
    hue='parental_level_of_education', 
    data=dataset, 
    ci=0, 
    orient='h'
).set(title='Plot')

plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11944\2466827646.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.barplot(

# %%
dataset
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
sns.relplot(x=dataset['parental_level_of_education'], y=dataset["race_ethnicity"], hue=dataset['math_score'], size=  dataset['reading_score'],
            sizes=(40, 400), palette="spring",
            height=6, data=dataset).set(title='Salary by Education Level,Gender,Experience');
